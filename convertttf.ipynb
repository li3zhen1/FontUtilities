# %%
import os
from fontTools import ttLib

system_font_path = "/Library/Fonts/"

list = os.listdir(system_font_path)

def rename_font(font, from_str = "SF", to_str="SF-TrueType"):
    for nr in font['name'].names:
        nr_str = nr.__str__() 
        if "SF" in nr_str :
            # print(nr_str)
            font['name'].setName(
                nr_str.replace(from_str, to_str),
                nr.nameID, nr.platformID, nr.platEncID, nr.langID
            )
    return font

def convert_to_ttf(font_name, from_str = "SF", to_str="SF-TrueType"):
    new_font_name = font_name[:-3].replace(from_str, to_str) + "ttf"
    command  = "otf2ttf " + system_font_path + font_name + " -o "+ "./"+new_font_name
    print(command)
    os.system(command)
    return new_font_name

# %%
for f in list:
    if f.endswith(".otf") and f.startswith("SF"):
        ft_name = convert_to_ttf(f)
        rename_font(ttLib.TTFont(ft_name)).save(ft_name)
# Out:
# otf2ttf /Library/Fonts/SF-Pro-Display-Thin.otf -o ./SF-TrueType-Pro-Display-Thin.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Medium.otf -o ./SF-TrueType-Compact-Rounded-Medium.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Heavy.otf -o ./SF-TrueType-Compact-Rounded-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-SemiboldItalic.otf -o ./SF-TrueType-Pro-Display-SemiboldItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Black.otf -o ./SF-TrueType-Compact-Text-Black.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Semibold.otf -o ./SF-TrueType-Compact-Text-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-UltralightItalic.otf -o ./SF-TrueType-Pro-Text-UltralightItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Heavy.otf -o ./SF-TrueType-Pro-Text-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Mono-Bold.otf -o ./SF-TrueType-Mono-Bold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-RegularItalic.otf -o ./SF-TrueType-Pro-Display-RegularItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Black.otf -o ./SF-TrueType-Compact-Display-Black.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-UltralightItalic.otf -o ./SF-TrueType-Compact-Text-UltralightItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Light.otf -o ./SF-TrueType-Pro-Display-Light.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Semibold.otf -o ./SF-TrueType-Compact-Display-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Semibold.otf -o ./SF-TrueType-Pro-Rounded-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Regular.otf -o ./SF-TrueType-Pro-Display-Regular.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Ultralight.otf -o ./SF-TrueType-Compact-Display-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Mono-Light.otf -o ./SF-TrueType-Mono-Light.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-MediumItalic.otf -o ./SF-TrueType-Pro-Text-MediumItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Bold.otf -o ./SF-TrueType-Pro-Display-Bold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Regular.otf -o ./SF-TrueType-Pro-Rounded-Regular.ttf
# otf2ttf /Library/Fonts/SF-Mono-Regular.otf -o ./SF-TrueType-Mono-Regular.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Medium.otf -o ./SF-TrueType-Pro-Display-Medium.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Thin.otf -o ./SF-TrueType-Compact-Text-Thin.ttf
# otf2ttf /Library/Fonts/SF-Mono-Heavy.otf -o ./SF-TrueType-Mono-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-RegularItalic.otf -o ./SF-TrueType-Compact-Text-RegularItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Heavy.otf -o ./SF-TrueType-Pro-Display-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Mono-BoldItalic.otf -o ./SF-TrueType-Mono-BoldItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Bold.otf -o ./SF-TrueType-Compact-Display-Bold.ttf
# otf2ttf /Library/Fonts/SF-Mono-MediumItalic.otf -o ./SF-TrueType-Mono-MediumItalic.ttf
# otf2ttf /Library/Fonts/SF-Mono-RegularItalic.otf -o ./SF-TrueType-Mono-RegularItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Thin.otf -o ./SF-TrueType-Compact-Display-Thin.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Light.otf -o ./SF-TrueType-Compact-Rounded-Light.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Regular.otf -o ./SF-TrueType-Compact-Rounded-Regular.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Ultralight.otf -o ./SF-TrueType-Compact-Rounded-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Regular.otf -o ./SF-TrueType-Compact-Display-Regular.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Bold.otf -o ./SF-TrueType-Compact-Text-Bold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Light.otf -o ./SF-TrueType-Pro-Text-Light.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Black.otf -o ./SF-TrueType-Pro-Rounded-Black.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Semibold.otf -o ./SF-TrueType-Compact-Rounded-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Semibold.otf -o ./SF-TrueType-Pro-Display-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-BoldItalic.otf -o ./SF-TrueType-Compact-Text-BoldItalic.ttf
# otf2ttf /Library/Fonts/SF-Mono-Semibold.otf -o ./SF-TrueType-Mono-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Black.otf -o ./SF-TrueType-Compact-Rounded-Black.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-BlackItalic.otf -o ./SF-TrueType-Pro-Text-BlackItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Black.otf -o ./SF-TrueType-Pro-Text-Black.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Medium.otf -o ./SF-TrueType-Compact-Display-Medium.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Light.otf -o ./SF-TrueType-Pro-Rounded-Light.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Heavy.otf -o ./SF-TrueType-Compact-Text-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Regular.otf -o ./SF-TrueType-Pro-Text-Regular.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Ultralight.otf -o ./SF-TrueType-Pro-Text-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Bold.otf -o ./SF-TrueType-Pro-Text-Bold.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-ThinItalic.otf -o ./SF-TrueType-Compact-Text-ThinItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Bold.otf -o ./SF-TrueType-Compact-Rounded-Bold.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Thin.otf -o ./SF-TrueType-Pro-Text-Thin.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Heavy.otf -o ./SF-TrueType-Compact-Display-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Compact-Rounded-Thin.otf -o ./SF-TrueType-Compact-Rounded-Thin.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-LightItalic.otf -o ./SF-TrueType-Compact-Text-LightItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-MediumItalic.otf -o ./SF-TrueType-Pro-Display-MediumItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-HeavyItalic.otf -o ./SF-TrueType-Compact-Text-HeavyItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-HeavyItalic.otf -o ./SF-TrueType-Pro-Display-HeavyItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Ultralight.otf -o ./SF-TrueType-Pro-Display-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-UltralightItalic.otf -o ./SF-TrueType-Pro-Display-UltralightItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-LightItalic.otf -o ./SF-TrueType-Pro-Display-LightItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-MediumItalic.otf -o ./SF-TrueType-Compact-Text-MediumItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Thin.otf -o ./SF-TrueType-Pro-Rounded-Thin.ttf
# otf2ttf /Library/Fonts/SF-Mono-SemiboldItalic.otf -o ./SF-TrueType-Mono-SemiboldItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Ultralight.otf -o ./SF-TrueType-Compact-Text-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-BlackItalic.otf -o ./SF-TrueType-Compact-Text-BlackItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-ThinItalic.otf -o ./SF-TrueType-Pro-Text-ThinItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Display-Light.otf -o ./SF-TrueType-Compact-Display-Light.ttf
# otf2ttf /Library/Fonts/SF-Mono-Medium.otf -o ./SF-TrueType-Mono-Medium.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Medium.otf -o ./SF-TrueType-Compact-Text-Medium.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-BlackItalic.otf -o ./SF-TrueType-Pro-Display-BlackItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-Black.otf -o ./SF-TrueType-Pro-Display-Black.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Medium.otf -o ./SF-TrueType-Pro-Rounded-Medium.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-BoldItalic.otf -o ./SF-TrueType-Pro-Text-BoldItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-RegularItalic.otf -o ./SF-TrueType-Pro-Text-RegularItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Semibold.otf -o ./SF-TrueType-Pro-Text-Semibold.ttf
# otf2ttf /Library/Fonts/SF-Mono-LightItalic.otf -o ./SF-TrueType-Mono-LightItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-HeavyItalic.otf -o ./SF-TrueType-Pro-Text-HeavyItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-ThinItalic.otf -o ./SF-TrueType-Pro-Display-ThinItalic.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-SemiboldItalic.otf -o ./SF-TrueType-Compact-Text-SemiboldItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-LightItalic.otf -o ./SF-TrueType-Pro-Text-LightItalic.ttf
# otf2ttf /Library/Fonts/SF-Mono-HeavyItalic.otf -o ./SF-TrueType-Mono-HeavyItalic.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Ultralight.otf -o ./SF-TrueType-Pro-Rounded-Ultralight.ttf
# otf2ttf /Library/Fonts/SF-Pro-Text-Medium.otf -o ./SF-TrueType-Pro-Text-Medium.ttf
# otf2ttf /Library/Fonts/SF-Pro-Rounded-Heavy.otf -o ./SF-TrueType-Pro-Rounded-Heavy.ttf
# otf2ttf /Library/Fonts/SF-Compact-Text-Regular.otf -o ./SF-TrueType-Compact-Text-Regular.ttf
# otf2ttf /Library/Fonts/SF-Pro-Display-BoldItalic.otf -o ./SF-TrueType-Pro-Display-BoldItalic.ttf
